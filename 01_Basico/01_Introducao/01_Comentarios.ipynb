# %% [markdown]
# # Comentarios
# ***

# %% [markdown]
# #### Comentario de uma linha

# %%
# Comentario de uma linha para métodos privados

# %% [markdown]
# #### Cometario de multiplas linhas

# %%
'''
Comentarios
de
varias
linhas
'''
