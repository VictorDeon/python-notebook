# %% [markdown]
# # while
# ***

# %% [markdown]
# O laço while sempre precisa de um criterio de parada

# %% [markdown]
# ***
# ### Exemplo
# ***

# %%
counter = 0
while counter <= 6:
    print(counter)
    counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
counter = 0
while True:
    print(counter)
    if (counter == 5):
        break
    counter += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
