# %% [markdown]
# ## Agente de IA com LangGraph
# ***

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
GEMINI_API_KEY = os.environ.get("GEMINI_API_KEY")
TAVILY_API_KEY = os.environ.get("TAVILY_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
model_template = PromptTemplate(
    template="Me diga quais os impactos da IA no assunto {subject}",
    input_variables=["subject"]
)

# %%
chain = model_template | llm | StrOutputParser

# %%
response = chain.invoke({'subject': 'Agricultura'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 response = chain.invoke({'subject': 'Agricultura'})
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:5018, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5003 """Invoke this `Runnable` synchronously.
#    5004
#    5005 Args:
#    (...)
#    5015
#    5016 """
#    5017 if hasattr(self, "func"):
# -> 5018     return self._call_with_config(
#    5019         self._invoke,
#    5020         input,
#    5021         ensure_config(config),
#    5022         **kwargs,
#    5023     )
#    5024 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5025 raise TypeError(msg)
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:2060, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2056     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2057     with set_config_context(child_config) as context:
#    2058         output = cast(
#    2059             "Output",
# -> 2060             context.run(
#    2061                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2062                 func,
#    2063                 input_,
#    2064                 config,
#    2065                 run_manager,
#    2066                 **kwargs,
#    2067             ),
#    2068         )
#    2069 except BaseException as e:
#    2070     run_manager.on_chain_error(e)
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/runnables/config.py:452, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     450 if run_manager is not None and accepts_run_manager(func):
#     451     kwargs["run_manager"] = run_manager
# --> 452 return func(input, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:4875, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4873                 output = chunk
#    4874 else:
# -> 4875     output = call_func_with_variable_args(
#    4876         self.func, input_, config, run_manager, **kwargs
#    4877     )
#    4878 # If the output is a Runnable, invoke it
#    4879 if isinstance(output, Runnable):
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/runnables/config.py:452, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     450 if run_manager is not None and accepts_run_manager(func):
#     451     kwargs["run_manager"] = run_manager
# --> 452 return func(input, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given

# %%
print(response)
